# %%
#https://medium.com/analytics-vidhya/how-to-use-google-colab-with-github-via-google-drive-68efb23a42d

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !python3 setup.py install
#!pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" .

# %%
# %cd /content/drive/MyDrive/nlp_lab/Github/group_loss
# Out:
# /content/drive/MyDrive/nlp_lab/Github/group_loss

# %%
# !python train.py
# Out:
# train.py:3: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import logging, imp
# Traceback (most recent call last):
#   File "train.py", line 138, in <module>
#     model = net.load_net(dataset=args.dataset_name, net_type=args.net_type, nb_classes=args.nb_classes)
#   File "/content/drive/MyDrive/nlp_lab/Github/group_loss/net/load_trained_net.py", line 12, in load_net
#     model.load_state_dict(torch.load('net/finetuned_' + dataset + '_' + net_type + '.pth'))
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 713, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 930, in _legacy_load
#     result = unpickler.load()
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 876, in persistent_load
#     wrap_storage=restore_location(obj, location),
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 176, in default_restore_location
#     result = fn(storage, location)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 152, in _cuda_deserialize
#     device = validate_cuda_device(location)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 136, in validate_cuda_device
#     raise RuntimeError('Attempting to deserialize object on a CUDA '
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
# !git commit -am "updated start notebook"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@786c02b49193.(none)')

# %%
git co
